# %% [markdown]
# ## This Notebook gives performs Data Splitting and Resizing of Images (to load in Google Drive - Colab)

# %% [markdown]
# #  <font color='red'>Table of Contents</font>

# %% [markdown]
# [6. Train Validation Split](#section6)<br>
# [7. Resize and save](#section7)<br>
# [8. Image Pre Processing and save](#section8)<br>

# %%
# !mkdir test_images_resized
# !mkdir test_images_resized_preprocessed
# !mkdir train_images_resized
# !mkdir train_images_resized_preprocessed

# %%
#ref - https://stackoverflow.com/questions/14463277/how-to-disable-python-warnings

# Basic Libs..
import multiprocessing
from multiprocessing.pool import ThreadPool
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
from tqdm import tqdm,tqdm_notebook
from prettytable import PrettyTable
import pickle
import os
print('CWD is ',os.getcwd())

# Vis Libs..
from sklearn.manifold import TSNE
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["axes.grid"] = False

# Image Libs.
from PIL import Image
import cv2

# sklearn libs..
from sklearn.model_selection import train_test_split

# DL Libs..
import keras
from keras import applications
from keras.preprocessing.image import ImageDataGenerator,img_to_array,array_to_img,load_img
from keras import optimizers,Model,Sequential
from keras.layers import Input,GlobalAveragePooling2D,Dropout,Dense,Activation
from keras.callbacks import EarlyStopping,ReduceLROnPlateau
# Out:
# CWD is  /home/siddhu/projects/apto

# %% [markdown]
# #  <a id = 'section6'> <font color='red'>  6. Train Validation Split</font> </a>

# %%
'''
This function reads data from the respective train and test directories
'''

def load_data():
    train = pd.read_csv('train.csv')
    test = pd.read_csv('test.csv')
    
    train_dir = os.path.join('./','train_images/')
    test_dir = os.path.join('./','test_images/')
    
    train['file_path'] = train['id_code'].map(lambda x: os.path.join(train_dir,'{}.png'.format(x)))
    test['file_path'] = test['id_code'].map(lambda x: os.path.join(test_dir,'{}.png'.format(x)))
    
    train['file_name'] = train["id_code"].apply(lambda x: x + ".png")
    test['file_name'] = test["id_code"].apply(lambda x: x + ".png")
    
    train['diagnosis'] = train['diagnosis'].astype(str)
    
    return train,test

# %%
df_train,df_test = load_data()
print(df_train.shape,df_test.shape,'\n')
df_train.head(6)
# Out:
# (3662, 4) (1928, 3)
#         id_code diagnosis                        file_path         file_name
# 0  000c1434d8d7         2  ./train_images/000c1434d8d7.png  000c1434d8d7.png
# 1  001639a390f0         4  ./train_images/001639a390f0.png  001639a390f0.png
# 2  0024cdab0c1e         1  ./train_images/0024cdab0c1e.png  0024cdab0c1e.png
# 3  002c21358ce6         0  ./train_images/002c21358ce6.png  002c21358ce6.png
# 4  005b95c28852         0  ./train_images/005b95c28852.png  005b95c28852.png
# 5  0083ee8054ee         4  ./train_images/0083ee8054ee.png  0083ee8054ee.png

# %%
df_train_train,df_train_test = train_test_split(df_train,test_size = 0.2)
print(df_train_train.shape,df_train_test.shape)
# Out:
# (2929, 4) (733, 4)

# %%
'''This Function Plots a Bar plot of output Classes Distribution'''

def plot_classes(df,title):
    df_group = pd.DataFrame(df.groupby('diagnosis').agg('size').reset_index())
    df_group.columns = ['diagnosis','count']

    sns.set(rc={'figure.figsize':(10,5)}, style = 'whitegrid')
    sns.barplot(x = 'diagnosis',y='count',data = df_group,palette = "Blues_d")
    plt.title('Output Class Distribution ' + str(title))
    plt.show()

# %%
plot_classes(df_train_train,"TRAIN DATA")

# %%
plot_classes(df_train_test,'VALIDATION DATA')

# %%
file = open('df_train_train', 'wb')
pickle.dump(df_train_train, file)
file.close()

file = open('df_train_test', 'wb')
pickle.dump(df_train_test, file)
file.close()

# %%
file = open('df_train_train', 'rb')
df_train_train = pickle.load(file)
file.close()

file = open('df_train_test', 'rb')
df_train_test = pickle.load(file)
file.close()

# %%
print(df_train_train.shape,df_train_test.shape)
print(len(os.listdir('./train_images_resized_preprocessed')),len(os.listdir('./test_images_resized_preprocessed')))
# Out:
# (2929, 4) (733, 4)
# 0 0

# %% [markdown]
# #  <a id = 'section7'> <font color='red'>  7. Resize and Save</font> </a>

# %%
IMG_SIZE  = 512

# %%
'''Function loads an image from Folder , Resizes and saves in another directory '''

def image_resize_save_test(file):
    input_filepath = os.path.join('./','train_images','{}.png'.format(file))
    output_filepath = os.path.join('./','test_images_resized','{}.png'.format(file))
    img = cv2.imread(input_filepath)
    cv2.imwrite(output_filepath, cv2.resize(img, (IMG_SIZE,IMG_SIZE)))
#image_resize_save(df_train.id_code.iloc[201])

# %%
'''This Function uses Multi processing for faster saving of images into folder'''

def multiprocess_image_downloader_test(process:int, imgs:list):
    """
    Inputs:
        process: (int) number of process to run
        imgs:(list) list of images
    """
    print(f'MESSAGE: Running {process} process')
    results = ThreadPool(process).map(image_resize_save_test, imgs)
    return results

# %%
# Use 6 cores
multiprocess_image_downloader_test(8, list(df_train_test.id_code.values))
# Out:
# MESSAGE: Running 8 process
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
def image_resize_save_train(file):
    input_filepath = os.path.join('./','train_images','{}.png'.format(file))
    print(input_filepath)
    output_filepath = os.path.join('./','train_images_resized','{}.png'.format(file))
    print(input_filepath,output_filepath)
    img = cv2.imread(input_filepath)
    cv2.imwrite(output_filepath, cv2.resize(img, (IMG_SIZE,IMG_SIZE)))

# %%
def multiprocess_image_downloader_train(process:int, imgs:list):
    """
    Inputs:
        process: (int) number of process to run
        imgs:(list) list of images
    """
    print(f'MESSAGE: Running {process} process')
    results = ThreadPool(process).map(image_resize_save_train, imgs)
    return results

# %%
multiprocess_image_downloader_train(8, list(df_train_train.id_code.values))
# Out:
# images_resized/bebb3f167654.png
# ./train_images/61da799bf0aa.png
# ./train_images/61da799bf0aa.png ./train_images_resized/61da799bf0aa.png
# ./train_images/fe674c2f73f5.png
# ./train_images/fe674c2f73f5.png ./train_images_resized/fe674c2f73f5.png
# ./train_images/4b6cb0bcfd44.png
# ./train_images/4b6cb0bcfd44.png ./train_images_resized/4b6cb0bcfd44.png
# ./train_images/6e44f6d04fc9.png
# ./train_images/6e44f6d04fc9.png ./train_images_resized/6e44f6d04fc9.png
# ./train_images/c80b0f27541a.png
# ./train_images/c80b0f27541a.png ./train_images_resized/c80b0f27541a.png
# ./train_images/76cab26493f1.png
# ./train_images/76cab26493f1.png ./train_images_resized/76cab26493f1.png
# ./train_images/842d697884f6.png
# ./train_images/842d697884f6.png ./train_images_resized/842d697884f6.png
# ./train_images/6b869f37cdf3.png
# ./train_images/6b869f37cdf3.png ./train_images_resized/6b869f37cdf3.png
# ./train_images/7b49041cbf17.png
# ./train_images/7b49041cbf17.png ./train_images_resized/7b49041cbf17.png
# ./train_images/81371b0c01ad.png
# ./train_images/81371b0c01ad.png ./train_images_resized/81371b0c01ad.png
# ./train_images/5712e2aa73a2.png
# ./train_images/5712e2aa73a2.png ./train_images_resized/5712e2aa73a2.png
# ./train_images/e2265c383348.png
# ./train_images/e2265c383348.png ./train_images_resized/e2265c383348.png
# ./train_images/6c4ec95dd8ba.png
# ./train_images/6c4ec95dd8ba.png ./train_images_resized/6c4ec95dd8ba.png
# ./train_images/fa9f1bc03f21.png
# ./train_images/fa9f1bc03f21.png ./train_images_resized/fa9f1bc03f21.png
# ./train_images/10ecc5292ab1.png
# ./train_images/10ecc5292ab1.png ./train_images_resized/10ecc5292ab1.png
# ./train_images/cf603a9ef2d5.png
# ./train_images/cf603a9ef2d5.png ./train_images_resized/cf603a9ef2d5.png
# ./train_images/9c6512166557.png
# ./train_images/9c6512166557.png ./train_images_resized/9c6512166557.png
# ./train_images/282bc792d23a.png
# ./train_images/282bc792d23a.png ./train_images_resized/282bc792d23a.png
# ./train_images/b70cb31b9abb.png
# ./train_images/b70cb31b9abb.png ./train_images_resized/b70cb31b9abb.png
# ./train_images/71c1a3cdbe47.png
# ./train_images/71c1a3cdbe47.png ./train_images_resized/71c1a3cdbe47.png
# ./train_images/6cb98da77e3e.png
# ./train_images/6cb98da77e3e.png ./train_images_resized/6cb98da77e3e.png
# ./train_images/5299a532f0e0.png
# ./train_images/5299a532f0e0.png ./train_images_resized/5299a532f0e0.png
# ./train_images/50d8249f7bc9.png
# ./train_images/50d8249f7bc9.png ./train_images_resized/50d8249f7bc9.png
# ./train_images/10bf25731c08.png
# ./train_images/10bf25731c08.png ./train_images_resized/10bf25731c08.png
# ./train_images/025a169a0bb0.png
# ./train_images/025a169a0bb0.png ./train_images_resized/025a169a0bb0.png
# ./train_images/5265dc9acdf8.png
# ./train_images/5265dc9acdf8.png ./train_images_resized/5265dc9acdf8.png
# ./train_images/358d2224de73.png
# ./train_images/358d2224de73.png ./train_images_resized/358d2224de73.png
# ./train_images/6d454444f17c.png
# ./train_images/6d454444f17c.png ./train_images_resized/6d454444f17c.png
# ./train_images/57a710de68a4.png
# ./train_images/57a710de68a4.png ./train_images_resized/57a710de68a4.png
# ./train_images/04a6fc58dabc.png
# ./train_images/04a6fc58dabc.png ./train_images_resized/04a6fc58dabc.png
# ./train_images/f7edc074f06b.png
# ./train_images/f7edc074f06b.png ./train_images_resized/f7edc074f06b.png
# ./train_images/a0adbe677508.png
# ./train_images/a0adbe677508.png ./train_images_resized/a0adbe677508.png
# ./train_images/838b3e4d0bb4.png
# ./train_images/838b3e4d0bb4.png ./train_images_resized/838b3e4d0bb4.png
# ./train_images/c3c8fdda50c0.png
# ./train_images/c3c8fdda50c0.png ./train_images_resized/c3c8fdda50c0.png
# ./train_images/1db6bb46c102.png
# ./train_images/1db6bb46c102.png ./train_images_resized/1db6bb46c102.png
# ./train_images/cbf0394039f8.png
# ./train_images/cbf0394039f8.png ./train_images_resized/cbf0394039f8.png
# ./train_images/35777eb7859d.png
# ./train_images/35777eb7859d.png ./train_images_resized/35777eb7859d.png
# ./train_images/97bf61736b86.png
# ./train_images/97bf61736b86.png ./train_images_resized/97bf61736b86.png
# ./train_images/90a9a41eec6d.png
# ./train_images/90a9a41eec6d.png ./train_images_resized/90a9a41eec6d.png
# ./train_images/c68dfa021d62.png
# ./train_images/c68dfa021d62.png ./train_images_resized/c68dfa021d62.png
# ./train_images/a80dab8eddf4.png
# ./train_images/a80dab8eddf4.png ./train_images_resized/a80dab8eddf4.png
# ./train_images/3486f7096276.png
# ./train_images/3486f7096276.png ./train_images_resized/3486f7096276.png
# ./train_images/0a09aa7356c0.png
# ./train_images/0a09aa7356c0.png ./train_images_resized/0a09aa7356c0.png
# ./train_images/941d874c8afb.png
# ./train_images/941d874c8afb.png ./train_images_resized/941d874c8afb.png
# ./train_images/77e15f213b04.png
# ./train_images/77e15f213b04.png ./train_images_resized/77e15f213b04.png
# ./train_images/1e7ccd4a1c87.png
# ./train_images/1e7ccd4a1c87.png ./train_images_resized/1e7ccd4a1c87.png
# ./train_images/5ad3dabeb2cd.png
# ./train_images/5ad3dabeb2cd.png ./train_images_resized/5ad3dabeb2cd.png
# ./train_images/3748349334f6.png
# ./train_images/3748349334f6.png ./train_images_resized/3748349334f6.png
# ./train_images/58059e73d2d4.png
# ./train_images/58059e73d2d4.png ./train_images_resized/58059e73d2d4.png
# ./train_images/721214151233.png
# ./train_images/721214151233.png ./train_images_resized/721214151233.png
# ./train_images/f4de9620e3f2.png
# ./train_images/f4de9620e3f2.png ./train_images_resized/f4de9620e3f2.png
# ./train_images/4ecd1fdd1435.png
# ./train_images/4ecd1fdd1435.png ./train_images_resized/4ecd1fdd1435.png
# ./train_images/13d71389563f.png
# ./train_images/13d71389563f.png ./train_images_resized/13d71389563f.png
# ./train_images/4b422b48d0d4.png
# ./train_images/4b422b48d0d4.png ./train_images_resized/4b422b48d0d4.png
# ./train_images/de38adaae009.png
# ./train_images/de38adaae009.png ./train_images_resized/de38adaae009.png
# ./train_images/e087bd4b88f2.png
# ./train_images/e087bd4b88f2.png ./train_images_resized/e087bd4b88f2.png
# ./train_images/cae33655ca00.png
# ./train_images/cae33655ca00.png ./train_images_resized/cae33655ca00.png
# ./train_images/4a213b405ee4.png
# ./train_images/4a213b405ee4.png ./train_images_resized/4a213b405ee4.png
# ./train_images/437cbec4a3f8.png
# ./train_images/437cbec4a3f8.png ./train_images_resized/437cbec4a3f8.png
# ./train_images/c56293f53191.png
# ./train_images/c56293f53191.png ./train_images_resized/c56293f53191.png
# ./train_images/d1a24527a15d.png
# ./train_images/d1a24527a15d.png ./train_images_resized/d1a24527a15d.png
# ./train_images/bcb0498ed2c1.png
# ./train_images/bcb0498ed2c1.png ./train_images_resized/bcb0498ed2c1.png
# ./train_images/3402124408ea.png
# ./train_images/3402124408ea.png ./train_images_resized/3402124408ea.png
# ./train_images/2d7666b8884f.png
# ./train_images/2d7666b8884f.png ./train_images_resized/2d7666b8884f.png
# ./train_images/4d17559ac1e2.png
# ./train_images/4d17559ac1e2.png ./train_images_resized/4d17559ac1e2.png
# ./train_images/bb08949dd70a.png
# ./train_images/bb08949dd70a.png ./train_images_resized/bb08949dd70a.png
# ./train_images/07929d32b5b3.png
# ./train_images/07929d32b5b3.png ./train_images_resized/07929d32b5b3.png
# ./train_images/b82dfa63a75f.png
# ./train_images/b82dfa63a75f.png ./train_images_resized/b82dfa63a75f.png
# ./train_images/c1819db0aece.png
# ./train_images/c1819db0aece.png ./train_images_resized/c1819db0aece.png
# ./train_images/ef476be214d4.png
# ./train_images/ef476be214d4.png ./train_images_resized/ef476be214d4.png
# ./train_images/7b87b0015282.png
# ./train_images/7b87b0015282.png ./train_images_resized/7b87b0015282.png
# ./train_images/00cc2b75cddd.png
# ./train_images/00cc2b75cddd.png ./train_images_resized/00cc2b75cddd.png
# ./train_images/c40976189f22.png
# ./train_images/c40976189f22.png ./train_images_resized/c40976189f22.png
# ./train_images/94145d1f42cf.png
# ./train_images/94145d1f42cf.png ./train_images_resized/94145d1f42cf.png
# ./train_images/c3e02d4a1798.png
# ./train_images/c3e02d4a1798.png ./train_images_resized/c3e02d4a1798.png
# ./train_images/b0cc9f8d06e4.png
# ./train_images/b0cc9f8d06e4.png ./train_images_resized/b0cc9f8d06e4.png
# ./train_images/521b5377a727.png
# ./train_images/521b5377a727.png ./train_images_resized/521b5377a727.png
# ./train_images/881ec6186e68.png
# ./train_images/881ec6186e68.png ./train_images_resized/881ec6186e68.png
# ./train_images/8d7bb0649a02.png
# ./train_images/8d7bb0649a02.png ./train_images_resized/8d7bb0649a02.png
# ./train_images/946545473380.png
# ./train_images/946545473380.png ./train_images_resized/946545473380.png
# ./train_images/a94da3d3b5c0.png
# ./train_images/a94da3d3b5c0.png ./train_images_resized/a94da3d3b5c0.png
# ./train_images/875d2ffcbf47.png
# ./train_images/875d2ffcbf47.png ./train_images_resized/875d2ffcbf47.png
# ./train_images/66375b3c64db.png
# ./train_images/66375b3c64db.png ./train_images_resized/66375b3c64db.png
# ./train_images/a81b06f50612.png
# ./train_images/a81b06f50612.png ./train_images_resized/a81b06f50612.png
# ./train_images/4a693dd3921a.png
# ./train_images/4a693dd3921a.png ./train_images_resized/4a693dd3921a.png
# ./train_images/e6a6acf7fca1.png
# ./train_images/e6a6acf7fca1.png ./train_images_resized/e6a6acf7fca1.png
# ./train_images/415d5c5e785f.png
# ./train_images/415d5c5e785f.png ./train_images_resized/415d5c5e785f.png
# ./train_images/c96f743915b5.png
# ./train_images/c96f743915b5.png ./train_images_resized/c96f743915b5.png
# ./train_images/d4f32b9c07df.png
# ./train_images/d4f32b9c07df.png ./train_images_resized/d4f32b9c07df.png
# ./train_images/04efb1a284cc.png
# ./train_images/04efb1a284cc.png ./train_images_resized/04efb1a284cc.png
# ./train_images/8b76c3c5cb3e.png
# ./train_images/8b76c3c5cb3e.png ./train_images_resized/8b76c3c5cb3e.png
# ./train_images/2209daf71aab.png
# ./train_images/2209daf71aab.png ./train_images_resized/2209daf71aab.png
# ./train_images/2fdfb80ea53c.png
# ./train_images/2fdfb80ea53c.png ./train_images_resized/2fdfb80ea53c.png
# ./train_images/190a309f2cc5.png
# ./train_images/190a309f2cc5.png ./train_images_resized/190a309f2cc5.png
# ./train_images/d3de0d313d61.png
# ./train_images/d3de0d313d61.png ./train_images_resized/d3de0d313d61.png
# ./train_images/59e5212f7139.png
# ./train_images/59e5212f7139.png ./train_images_resized/59e5212f7139.png
# ./train_images/d8cdb7d7283a.png
# ./train_images/d8cdb7d7283a.png ./train_images_resized/d8cdb7d7283a.png
# ./train_images/b3c0c3330278.png
# ./train_images/b3c0c3330278.png ./train_images_resized/b3c0c3330278.png
# ./train_images/435414ccccf7.png
# ./train_images/435414ccccf7.png ./train_images_resized/435414ccccf7.png
# ./train_images/ed88faaa325a.png
# ./train_images/ed88faaa325a.png ./train_images_resized/ed88faaa325a.png
# ./train_images/a4012932e18d.png
# ./train_images/a4012932e18d.png ./train_images_resized/a4012932e18d.png
# ./train_images/52886bed8a07.png
# ./train_images/52886bed8a07.png ./train_images_resized/52886bed8a07.png
# ./train_images/03ff7d159f10.png
# ./train_images/03ff7d159f10.png ./train_images_resized/03ff7d159f10.png
# ./train_images/0f882877bf13.png
# ./train_images/0f882877bf13.png ./train_images_resized/0f882877bf13.png
# ./train_images/94dcb491143f.png
# ./train_images/94dcb491143f.png ./train_images_resized/94dcb491143f.png
# ./train_images/d8404680bba6.png
# ./train_images/d8404680bba6.png ./train_images_resized/d8404680bba6.png
# ./train_images/b019a49787c1.png
# ./train_images/b019a49787c1.png ./train_images_resized/b019a49787c1.png
# ./train_images/37c4dfe03aba.png
# ./train_images/37c4dfe03aba.png ./train_images_resized/37c4dfe03aba.png
# ./train_images/fa748b57262b.png
# ./train_images/fa748b57262b.png ./train_images_resized/fa748b57262b.png
# ./train_images/578109578b46.png
# ./train_images/578109578b46.png ./train_images_resized/578109578b46.png
# ./train_images/06b71823f9cd.png
# ./train_images/06b71823f9cd.png ./train_images_resized/06b71823f9cd.png
# ./train_images/b90bc89ce8d8.png
# ./train_images/b90bc89ce8d8.png ./train_images_resized/b90bc89ce8d8.png
# ./train_images/0b8bdec9d869.png
# ./train_images/0b8bdec9d869.png ./train_images_resized/0b8bdec9d869.png
# ./train_images/9d9bfefa809c.png
# ./train_images/9d9bfefa809c.png ./train_images_resized/9d9bfefa809c.png
# ./train_images/40c24aded50c.png
# ./train_images/40c24aded50c.png ./train_images_resized/40c24aded50c.png
# ./train_images/f71bea807c96.png
# ./train_images/f71bea807c96.png ./train_images_resized/f71bea807c96.png
# ./train_images/4393c5bc576a.png
# ./train_images/4393c5bc576a.png ./train_images_resized/4393c5bc576a.png
# ./train_images/259d30f693b6.png
# ./train_images/259d30f693b6.png ./train_images_resized/259d30f693b6.png
# ./train_images/39fd8ef3a45c.png
# ./train_images/39fd8ef3a45c.png ./train_images_resized/39fd8ef3a45c.png
# ./train_images/e1b8acb1cea1.png
# ./train_images/e1b8acb1cea1.png ./train_images_resized/e1b8acb1cea1.png
# ./train_images/a664d2055886.png
# ./train_images/a664d2055886.png ./train_images_resized/a664d2055886.png
# ./train_images/499c8df39222.png
# ./train_images/499c8df39222.png ./train_images_resized/499c8df39222.png
# ./train_images/e85d410d6836.png
# ./train_images/e85d410d6836.png ./train_images_resized/e85d410d6836.png
# ./train_images/a82a12ad3fb1.png
# ./train_images/a82a12ad3fb1.png ./train_images_resized/a82a12ad3fb1.png
# ./train_images/98e44127872f.png
# ./train_images/98e44127872f.png ./train_images_resized/98e44127872f.png
# ./train_images/ad944bd56bb6.png
# ./train_images/ad944bd56bb6.png ./train_images_resized/ad944bd56bb6.png
# ./train_images/a763661f98a5.png
# ./train_images/a763661f98a5.png ./train_images_resized/a763661f98a5.png
# ./train_images/144b01e7b993.png
# ./train_images/144b01e7b993.png ./train_images_resized/144b01e7b993.png
# ./train_images/a77eb914b383.png
# ./train_images/a77eb914b383.png ./train_images_resized/a77eb914b383.png
# ./train_images/91a88d3b0358.png
# ./train_images/91a88d3b0358.png ./train_images_resized/91a88d3b0358.png
# ./train_images/4462fba1d2a1.png
# ./train_images/4462fba1d2a1.png ./train_images_resized/4462fba1d2a1.png
# ./train_images/2b07790a2422.png
# ./train_images/2b07790a2422.png ./train_images_resized/2b07790a2422.png
# ./train_images/8a25a080f28f.png
# ./train_images/8a25a080f28f.png ./train_images_resized/8a25a080f28f.png
# ./train_images/4350a1b2f3cb.png
# ./train_images/4350a1b2f3cb.png ./train_images_resized/4350a1b2f3cb.png
# ./train_images/157d17349cc6.png
# ./train_images/157d17349cc6.png ./train_images_resized/157d17349cc6.png
# ./train_images/310c27067ac0.png
# ./train_images/310c27067ac0.png ./train_images_resized/310c27067ac0.png
# ./train_images/4c635a01593d.png
# ./train_images/4c635a01593d.png ./train_images_resized/4c635a01593d.png
# ./train_images/2a93334f663a.png
# ./train_images/2a93334f663a.png ./train_images_resized/2a93334f663a.png
# ./train_images/4b5ffea77373.png
# ./train_images/4b5ffea77373.png ./train_images_resized/4b5ffea77373.png
# ./train_images/bab776139279.png
# ./train_images/bab776139279.png ./train_images_resized/bab776139279.png
# ./train_images/cb547e723a16.png
# ./train_images/cb547e723a16.png ./train_images_resized/cb547e723a16.png
# ./train_images/e52ed5c29c5e.png
# ./train_images/e52ed5c29c5e.png ./train_images_resized/e52ed5c29c5e.png
# ./train_images/8446826853d0.png
# ./train_images/8446826853d0.png ./train_images_resized/8446826853d0.png
# ./train_images/7356dd08b0ae.png
# ./train_images/7356dd08b0ae.png ./train_images_resized/7356dd08b0ae.png
# ./train_images/2fefb720869a.png
# ./train_images/2fefb720869a.png ./train_images_resized/2fefb720869a.png
# ./train_images/89d2a7403a06.png
# ./train_images/89d2a7403a06.png ./train_images_resized/89d2a7403a06.png
# ./train_images/48fda42bd5d4.png
# ./train_images/48fda42bd5d4.png ./train_images_resized/48fda42bd5d4.png
# ./train_images/fa0c87bd75ce.png
# ./train_images/fa0c87bd75ce.png ./train_images_resized/fa0c87bd75ce.png
# ./train_images/94076a9fb9b5.png
# ./train_images/94076a9fb9b5.png ./train_images_resized/94076a9fb9b5.png
# ./train_images/15f8d769935c.png
# ./train_images/15f8d769935c.png ./train_images_resized/15f8d769935c.png
# ./train_images/3de8ad4151e1.png
# ./train_images/3de8ad4151e1.png ./train_images_resized/3de8ad4151e1.png
# ./train_images/a77dbec966d4.png
# ./train_images/a77dbec966d4.png ./train_images_resized/a77dbec966d4.png
# ./train_images/56e56aa08362.png
# ./train_images/56e56aa08362.png ./train_images_resized/56e56aa08362.png
# ./train_images/05339950962e.png
# ./train_images/05339950962e.png ./train_images_resized/05339950962e.png
# ./train_images/e0313be77035.png
# ./train_images/e0313be77035.png ./train_images_resized/e0313be77035.png
# ./train_images/fcc55ae641ae.png
# ./train_images/fcc55ae641ae.png ./train_images_resized/fcc55ae641ae.png
# ./train_images/1e742358e0b9.png
# ./train_images/1e742358e0b9.png ./train_images_resized/1e742358e0b9.png
# ./train_images/93802d1e3c41.png
# ./train_images/93802d1e3c41.png ./train_images_resized/93802d1e3c41.png
# ./train_images/10f36b0239fb.png
# ./train_images/10f36b0239fb.png ./train_images_resized/10f36b0239fb.png
# ./train_images/1caba2fb38f6.png
# ./train_images/1caba2fb38f6.png ./train_images_resized/1caba2fb38f6.png
# ./train_images/1bb0ddfe753a.png
# ./train_images/1bb0ddfe753a.png ./train_images_resized/1bb0ddfe753a.png
# ./train_images/d51b3fe0fa1b.png
# ./train_images/d51b3fe0fa1b.png ./train_images_resized/d51b3fe0fa1b.png
# ./train_images/61d9c88a3a4b.png
# ./train_images/61d9c88a3a4b.png ./train_images_resized/61d9c88a3a4b.png
# ./train_images/97da093947e8.png
# ./train_images/97da093947e8.png ./train_images_resized/97da093947e8.png
# ./train_images/a2dff8dbc9f8.png
# ./train_images/a2dff8dbc9f8.png ./train_images_resized/a2dff8dbc9f8.png
# ./train_images/cd3fd04d72f5.png
# ./train_images/cd3fd04d72f5.png ./train_images_resized/cd3fd04d72f5.png
# ./train_images/d952dbfb0fe4.png
# ./train_images/d952dbfb0fe4.png ./train_images_resized/d952dbfb0fe4.png
# ./train_images/b1197f2cc9b3.png
# ./train_images/b1197f2cc9b3.png ./train_images_resized/b1197f2cc9b3.png
# ./train_images/5cf9127f251a.png
# ./train_images/5cf9127f251a.png ./train_images_resized/5cf9127f251a.png
# ./train_images/0104b032c141.png
# ./train_images/0104b032c141.png ./train_images_resized/0104b032c141.png
# ./train_images/ef5155990874.png
# ./train_images/ef5155990874.png ./train_images_resized/ef5155990874.png
# ./train_images/5db2e3a4594a.png
# ./train_images/5db2e3a4594a.png ./train_images_resized/5db2e3a4594a.png
# ./train_images/20404ec7b518.png
# ./train_images/20404ec7b518.png ./train_images_resized/20404ec7b518.png
# ./train_images/276b14f72328.png
# ./train_images/276b14f72328.png ./train_images_resized/276b14f72328.png
# ./train_images/af3b0115aad1.png
# ./train_images/af3b0115aad1.png ./train_images_resized/af3b0115aad1.png
# ./train_images/d5ad3362424c.png
# ./train_images/d5ad3362424c.png ./train_images_resized/d5ad3362424c.png
# ./train_images/afc345cc9145.png
# ./train_images/afc345cc9145.png ./train_images_resized/afc345cc9145.png
# ./train_images/917f76f360b6.png
# ./train_images/917f76f360b6.png ./train_images_resized/917f76f360b6.png
# ./train_images/54bdcdecd8f3.png
# ./train_images/54bdcdecd8f3.png ./train_images_resized/54bdcdecd8f3.png
# ./train_images/3b9817a39adf.png
# ./train_images/3b9817a39adf.png ./train_images_resized/3b9817a39adf.png
# ./train_images/10a5026eb8e6.png
# ./train_images/10a5026eb8e6.png ./train_images_resized/10a5026eb8e6.png
# ./train_images/a70d0f12a641.png
# ./train_images/a70d0f12a641.png ./train_images_resized/a70d0f12a641.png
# ./train_images/ff03f74667df.png
# ./train_images/ff03f74667df.png ./train_images_resized/ff03f74667df.png
# ./train_images/f86d1c404acb.png
# ./train_images/f86d1c404acb.png ./train_images_resized/f86d1c404acb.png
# ./train_images/2bbcfdc477db.png
# ./train_images/2bbcfdc477db.png ./train_images_resized/2bbcfdc477db.png
# ./train_images/8ead8f37423c.png
# ./train_images/8ead8f37423c.png ./train_images_resized/8ead8f37423c.png
# ./train_images/1ee355480567.png
# ./train_images/1ee355480567.png ./train_images_resized/1ee355480567.png
# ./train_images/b9fe7da14a32.png
# ./train_images/b9fe7da14a32.png ./train_images_resized/b9fe7da14a32.png
# ./train_images/de50dfa745f8.png
# ./train_images/de50dfa745f8.png ./train_images_resized/de50dfa745f8.png
# ./train_images/5905a9b06a73.png
# ./train_images/5905a9b06a73.png ./train_images_resized/5905a9b06a73.png
# ./train_images/f431f2e119d7.png
# ./train_images/f431f2e119d7.png ./train_images_resized/f431f2e119d7.png
# ./train_images/8bdb891661a8.png
# ./train_images/8bdb891661a8.png ./train_images_resized/8bdb891661a8.png
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]

# %%
image_resize_save_train('8714d17bb6da')
# Out:
# ./train_images/8714d17bb6da.png
# ./train_images/8714d17bb6da.png ./train_images_resized/8714d17bb6da.png

# %% [markdown]
# ##### Summary - Using Multiprocessing (6 cores), we managed to resize and save images within 10 minutes, and reducing IMG_SIZE to 512, thereby reducing disk-space from 20 GB (earlier) to 1 GB (after resizing). We shall load data into colab and start training models

# %% [markdown]
# #  <a id = 'section8'> <font color='red'>  8. Image Pre Processing and save</font> </a>

# %%
def crop_image_from_gray(img,tol=7):
    if img.ndim ==2:
        mask = img>tol
        return img[np.ix_(mask.any(1),mask.any(0))]
    elif img.ndim==3:
        gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        mask = gray_img>tol
        
        check_shape = img[:,:,0][np.ix_(mask.any(1),mask.any(0))].shape[0]
        if (check_shape == 0): # image is too dark so that we crop out everything,
            return img # return original image
        else:
            img1=img[:,:,0][np.ix_(mask.any(1),mask.any(0))]
            img2=img[:,:,1][np.ix_(mask.any(1),mask.any(0))]
            img3=img[:,:,2][np.ix_(mask.any(1),mask.any(0))]
    #         print(img1.shape,img2.shape,img3.shape)
            img = np.stack([img1,img2,img3],axis=-1)
    #         print(img.shape)
        return img

def circle_crop(img, sigmaX = 30):   
    """
    Create circular crop around image centre    
    """    
    img = crop_image_from_gray(img)    
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    height, width, depth = img.shape    
    
    x = int(width/2)
    y = int(height/2)
    r = np.amin((x,y))
    
    circle_img = np.zeros((height, width), np.uint8)
    cv2.circle(circle_img, (x,y), int(r), 1, thickness=-1)
    img = cv2.bitwise_and(img, img, mask=circle_img)
    img = crop_image_from_gray(img)
    img=cv2.addWeighted(img,4, cv2.GaussianBlur( img , (0,0) , sigmaX) ,-4 ,128)
    return img 

def preprocess_image_test(file):
    input_filepath = os.path.join('./','test_images_resized','{}.png'.format(file))
    output_filepath = os.path.join('./','test_images_resized_preprocessed','{}.png'.format(file))
    
    img = cv2.imread(input_filepath)
    img = circle_crop(img) 
    cv2.imwrite(output_filepath, cv2.resize(cv2.cvtColor(img, cv2.COLOR_BGR2RGB), (IMG_SIZE,IMG_SIZE)))

# %%
'''This Function uses Multi processing for faster saving of images into folder'''

def multiprocess_image_processor_test(process:int, imgs:list):
    """
    Inputs:
        process: (int) number of process to run
        imgs:(list) list of images
    """
    print(f'MESSAGE: Running {process} process')
    results = ThreadPool(process).map(preprocess_image_test, imgs)
    return results

# %%
# Use 6 cores
multiprocess_image_processor_test(8, list(df_train_test.id_code.values))
# Out:
# MESSAGE: Running 8 process
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
def preprocess_image_train(file):
    input_filepath = os.path.join('./','train_images_resized','{}.png'.format(file))
    output_filepath = os.path.join('./','train_images_resized_preprocessed','{}.png'.format(file))
    
    img = cv2.imread(input_filepath)
    img = circle_crop(img) 
    cv2.imwrite(output_filepath, cv2.resize(cv2.cvtColor(img, cv2.COLOR_BGR2RGB), (IMG_SIZE,IMG_SIZE)))

# %%
def multiprocess_image_processor_train(process:int, imgs:list):
    """
    Inputs:
        process: (int) number of process to run
        imgs:(list) list of images
    """
    print(f'MESSAGE: Running {process} process')
    results = ThreadPool(process).map(preprocess_image_train, imgs)
    return results

# %%
multiprocess_image_processor_train(8, list(df_train_train.id_code.values))
# Out:
# MESSAGE: Running 8 process
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]
